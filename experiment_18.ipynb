# %% [markdown]
# <a href="https://colab.research.google.com/github/Indraniel07/exp-18/blob/main/experiment_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Experiment 18 - Exploring Statistical and Specialized Data Visualisation Techniqe Indraniel Wandkar / 25070123126

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(0)
df=pd.DataFrame({'Category':['A','B','C','D','E'],
                 'Values':[0,70,30,90,60],
                 'Sales':np.random.randint(100,500,5),
                 'Profit':np.random.randint(10,100,5)})
print(df)
# Out:
#   Category  Values  Sales  Profit
# 0        A       0    272      77
# 1        B      70    147      19
# 2        C      30    217      93
# 3        D      90    292      31
# 4        E      60    423      46

# %%
#1.Area Plot
plt.figure()
plt.fill_between(df['Category'],df['Values'],color='green',alpha=0.2)
plt.xlabel('Category')
plt.ylabel('Values')
plt.title('Indraniel')
plt.show()

# %%
sns.set_theme(style='whitegrid')
plt.figure(figsize=(7,4))
plt.fill_between(df['Category'],df['Sales'],color='skyblue',alpha=0.2,label='Sales')
plt.fill_between(df['Category'],df['Profit'],color='orange',alpha=0.5,label='Profit')
plt.xlabel('Category')
plt.ylabel('Values')
plt.title('Indraniel')
plt.legend()
plt.show()

# %%
#2.Pie Chart
plt.figure()
plt.pie(df['Values'],labels=df['Category'],autopct='%1.2f%%')
plt.title('Indraniel')
plt.show()

# %%
#3.Donut Chart
plt.figure()
plt.pie(df['Values'],labels=df['Category'],autopct='%1.2f%%')
centre_circle=plt.Circle((0,0),0.70,fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Indraniel')
plt.show()

# %%
#4.Box Plot(Outliers Detection)
plt.figure()
sns.boxplot(x=df['Values'])
plt.title('Indraniel')
plt.show()

# %%
#5.Heatmap (Correlation)
plt.figure()
corr=df[['Sales','Profit']].corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title('Indraniel')
plt.show()

# %%
#Select only numeric Columns
corr = df[['Values', 'Sales', 'Profit']].corr()
plt.figure(figsize=(5,4))
sns.heatmap(corr, annot=True)
plt.title("Indraniel")
plt.show()

# %%
#6.Bubble Plot (3 Variable Chart)
plt.scatter(df['Sales'],df['Profit'],s=df['Values']*10) #Size of bubbles
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Indraniel')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
sns.scatterplot(x='Sales',y='Profit',hue='Values',data=df,size='Values',sizes=(50,300),palette='pastel')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Indraniel')
plt.show()
